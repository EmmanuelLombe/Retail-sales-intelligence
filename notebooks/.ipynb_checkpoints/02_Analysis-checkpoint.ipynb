# %%
import pandas as pd 

df= pd.read_csv("C:/Users/emmlo/Downloads/Retail_Sales_Intelligence/data/retail_sales_cleaned.csv")
df.head()
# Out:
#     order_id  order_date customer_id customer_name  age gender   region  \
# 0  ORD-03903  2024-08-15   CUST32603   Aarav Mehta   39  Other  Central
# 1  ORD-02198  2022-08-16   CUST07881  Sanjay Verma   28   Male     West
# 2  ORD-01348  2021-08-29   CUST49296  Pooja Sharma   41  Other     West
# 3  ORD-02076  2022-05-07   CUST05587   Priya Reddy   29  Other     West
# 4  ORD-00287  2020-07-05   CUST58035   Ritu Sharma    9   Male  Central
#
#         city product_category product_name  ...  unit_price  discount_pct  \
# 0     Raipur        Groceries        Sugar  ...      346.32          0.00
# 1     Mumbai           Beauty    Sunscreen  ...      858.66          0.08
# 2      Surat        Furniture         Sofa  ...    25941.32          0.14
# 3  Ahmedabad        Furniture    Bed Frame  ...    22071.92          0.17
# 4     Nagpur        Groceries  Cooking Oil  ...      320.06          0.31
#
#    sales_amount    profit  shipping_cost  payment_method  \
# ...

# %%
#Total revennue and profit 
total_revenue = df['sales_amount'].sum()
total_profit= df['profit'].sum()

print(f"The total Revenue is {total_revenue}")
print(f"The total Profit is {total_profit}")
# Out:
# The total Revenue is 266894969.01
# The total Profit is 50020895.23

# %%
#Total revenue and profit for each category
category_summary = df.groupby('product_category')[['sales_amount', 'profit']].sum().sort_values('sales_amount', ascending=False)
pd.options.display.float_format = '{:,.2f}'.format
print(category_summary)
# Out:
#                    sales_amount        profit
# product_category
# Electronics      157,170,278.37 19,295,549.67
# Furniture         57,130,398.63 16,134,849.68
# Sports            32,092,451.07  7,079,357.54
# Clothing          11,673,276.13  4,212,780.97
# Beauty             3,967,540.68  1,792,922.71
# Books              3,824,241.95  1,424,006.08
# Groceries          1,036,782.18     81,428.58

# %%
#PRofit margin for each category
category_summary['profit_margin_pct'] = category_summary['sales_amount']/category_summary['profit']
print(category_summary.sort_values('profit_margin_pct', ascending=False))
# Out:
#                    sales_amount        profit  profit_margin_pct
# product_category
# Groceries          1,036,782.18     81,428.58              12.73
# Electronics      157,170,278.37 19,295,549.67               8.15
# Sports            32,092,451.07  7,079,357.54               4.53
# Furniture         57,130,398.63 16,134,849.68               3.54
# Clothing          11,673,276.13  4,212,780.97               2.77
# Books              3,824,241.95  1,424,006.08               2.69
# Beauty             3,967,540.68  1,792,922.71               2.21

# %%
#Total revenue and profit for each region 
region_summary = df.groupby('region')[['sales_amount', 'profit']].sum().sort_values('sales_amount', ascending=False)
pd.options.display.float_format = '{:,.2f}'.format
print(region_summary)
# Out:
#          sales_amount        profit
# region
# South   74,283,796.33 13,426,744.13
# North   54,315,822.11 10,502,192.15
# East    49,430,294.17  8,872,941.99
# West    48,087,464.20  8,904,550.43
# Central 40,777,592.20  8,314,466.53

# %%
#Total revenue from different payment methods
payment_summary =  df.groupby('payment_method')[['sales_amount']].sum().sort_values('sales_amount', ascending=False)
print(payment_summary)

payment_summary = df['order_status'].value_counts()
print("\n Below is the number associated with different order statuses")
print(payment_summary)
# Out:
#                   sales_amount
# payment_method
# EMI              63,426,807.83
# Debit Card       43,016,312.15
# Cash on Delivery 42,291,274.76
# Net Banking      39,901,218.44
# UPI              39,616,904.10
# Credit Card      38,642,451.73
#
#  Below is the number associated with different order statuses
# order_status
# Delivered    2787
# Returned      623
# Cancelled     352
# Shipped       334
# Pending       184
# Name: count, dtype: int64
